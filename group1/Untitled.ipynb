# %%
import pandas as pd
data = pd.read_csv('./group1/movies_recommendation_data.csv', delimiter = ',')

# %%
data
# Out:
#     Movie ID                        Movie Name  IMDB Rating  Biography  Drama  \
# 0         58                The Imitation Game          8.0          1      1
# 1          8                        Ex Machina          7.7          0      1
# 2         46                  A Beautiful Mind          8.2          1      1
# 3         62                 Good Will Hunting          8.3          0      1
# 4         97                      Forrest Gump          8.8          0      1
# 5         98                                21          6.8          0      1
# 6         31                            Gifted          7.6          0      1
# 7          3               Travelling Salesman          5.9          0      1
# 8         51                            Avatar          7.9          0      0
# 9         47                    The Karate Kid          7.2          0      1
# 10        50            A Brilliant Young Mind          7.2          0      1
# ...

# %% [markdown]
# It would be a good time to read the scikit-learn page on nearest neighbors: https://scikit-learn.org/stable/modules/generated/sklearn.neighbors.NearestNeighbors.html
